# %% [markdown]
# #Practice Assignment

# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_iris

# %% [markdown]
# ##Q-1

# %%
X,y = load_iris(return_X_y=True)

# %%
np.unique(y)
# Out:
# array([0, 1, 2])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,random_state=42)

# %%
from sklearn.svm import SVC
svm = SVC(kernel='rbf',C=20,gamma='auto')
svm.fit(X_train,y_train)
svm.score(X_test,y_test)
# Out:
# 1.0

# %% [markdown]
# ##Q-2

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MinMaxScaler
pipe_1 = Pipeline([('scaler',MinMaxScaler()),('classifier',SVC(kernel='linear',decision_function_shape='ovr',C=1,class_weight=None))])
pipe_1.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('scaler', MinMaxScaler()),
#                 ('classifier', SVC(C=1, kernel='linear'))])

# %%
from sklearn.metrics import classification_report
y_hat=pipe_1.predict(X_test)
print(classification_report(y_test,y_hat))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        19
#            1       1.00      1.00      1.00        13
#            2       1.00      1.00      1.00        13
#
#     accuracy                           1.00        45
#    macro avg       1.00      1.00      1.00        45
# weighted avg       1.00      1.00      1.00        45

# %% [markdown]
# ##Q-3

# %%
data = load_iris(as_frame=True)

# %%
data.data.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
data.target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
idx=data.target[data.target==1]

# %%
idx_to_del=idx.index.values

# %%
labels=data.target.drop(index=idx_to_del)

# %%
features = data.data.drop(index=idx_to_del)

# %%
X=features.to_numpy()
y=labels.to_numpy()

# %%
y.shape
# Out:
# (100,)

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.5,random_state=0)

# %%
X_train.shape
# Out:
# (50, 4)

# %%
pipe_2 = Pipeline([('scaler',MinMaxScaler()),('classifier',SVC())])
pipe_2.fit(X_train,y_train)
y_hat=pipe_2.predict(X_test)
print(classification_report(y_test,y_hat))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        26
#            2       1.00      1.00      1.00        24
#
#     accuracy                           1.00        50
#    macro avg       1.00      1.00      1.00        50
# weighted avg       1.00      1.00      1.00        50

# %%
print(data.DESCR)
# Out:
# .. _iris_dataset:
#
# Iris plants dataset
# --------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 150 (50 in each of three classes)
#     :Number of Attributes: 4 numeric, predictive attributes and the class
#     :Attribute Information:
#         - sepal length in cm
#         - sepal width in cm
#         - petal length in cm
#         - petal width in cm
#         - class:
#                 - Iris-Setosa
#                 - Iris-Versicolour
#                 - Iris-Virginica
#
#     :Summary Statistics:
#
#     ============== ==== ==== ======= ===== ====================
#                     Min  Max   Mean    SD   Class Correlation
#     ============== ==== ==== ======= ===== ====================
#     sepal length:   4.3  7.9   5.84   0.83    0.7826
#     sepal width:    2.0  4.4   3.05   0.43   -0.4194
#     petal length:   1.0  6.9   3.76   1.76    0.9490  (high!)
#     petal width:    0.1  2.5   1.20   0.76    0.9565  (high!)
# ...

# %%
idx = np.where(y==1)[0]

# %% [markdown]
# ##Q-4

# %%
from sklearn.svm import LinearSVC
X,y = load_iris(return_X_y=True)
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,random_state=42)
svm = LinearSVC(loss='hinge',penalty='l2',random_state=42)
svm.fit(X_train,y_train)
svm.score(X_test,y_test)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# 0.9777777777777777

# %% [markdown]
# ##Q-5

# %%
from sklearn.model_selection import GridSearchCV
kernel=['linear','rbf']
C=[5,10,100]
param_grid= dict(kernel=kernel,C=C)
cv=10
grid = GridSearchCV(SVC(gamma='auto'),param_grid=param_grid,cv=cv,return_train_score=True)
grid.fit(X_train,y_train)
print("the best parameters are {0} with a score of {1:.2f}".format(grid.best_params_,grid.best_score_))
# Out:
# GridSearchCV(cv=10, estimator=SVC(gamma='auto'),
#              param_grid={'C': [5, 10, 100], 'kernel': ['linear', 'rbf']},
#              return_train_score=True)

# %%
grid.cv_results_
# Out:
# {'mean_fit_time': array([0.00116906, 0.0013315 , 0.00122178, 0.00130205, 0.00130775,
#         0.00130408]),
#  'mean_score_time': array([0.00059593, 0.00064018, 0.00062575, 0.00062664, 0.00057955,
#         0.00060799]),
#  'mean_test_score': array([0.96363636, 0.95363636, 0.95363636, 0.96363636, 0.94545455,
#         0.92545455]),
#  'mean_train_score': array([0.97356103, 0.97885778, 0.97040314, 0.97567749, 0.97569989,
#         0.98097424]),
#  'param_C': masked_array(data=[5, 5, 10, 10, 100, 100],
#               mask=[False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_kernel': masked_array(data=['linear', 'rbf', 'linear', 'rbf', 'linear', 'rbf'],
#               mask=[False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'C': 5, 'kernel': 'linear'},
#   {'C': 5, 'kernel': 'rbf'},
#   {'C': 10, 'kernel': 'linear'},
#   {'C': 10, 'kernel': 'rbf'},
# ...

# %%
grid.score(X_test,y_test)
# Out:
# 0.9777777777777777

# %% [markdown]
# # Graded Assignment

# %% [markdown]
# ##Q-1

# %%
X,y=load_iris(return_X_y=True)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,random_state=0)
kernel=['linear','rbf']
C=[1,15,25]
param_grid= dict(kernel=kernel,C=C)
cv=4
grid = GridSearchCV(SVC(gamma='auto'),param_grid=param_grid,cv=cv,return_train_score=True)
grid.fit(X_train,y_train)
print("the best parameters are {0} with a score of {1:.2f}".format(grid.best_params_,grid.best_score_))
# Out:
# the best parameters are {'C': 1, 'kernel': 'linear'} with a score of 0.98

# %% [markdown]
# ##Q-2

# %%
df = pd.read_csv('/content/Social_Network_Ads.csv')

# %%
df.head()
# Out:
#    Age  EstimatedSalary  Purchased
# 0   19            19000          0
# 1   35            20000          0
# 2   26            43000          0
# 3   27            57000          0
# 4   19            76000          0

# %%
features = df[['Age','EstimatedSalary']]
features.head()
# Out:
#    Age  EstimatedSalary
# 0   19            19000
# 1   35            20000
# 2   26            43000
# 3   27            57000
# 4   19            76000

# %%
labels=df['Purchased']

# %%
labels.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: Purchased, dtype: int64

# %%
X,y=features.to_numpy(),labels.to_numpy()

# %%
from sklearn.preprocessing import StandardScaler

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.25,random_state=0)
scaler=StandardScaler()
X_train=scaler.fit_transform(X_train)
X_test = scaler.fit_transform(X_test)
svm=SVC(kernel='linear',random_state=0)
svm.fit(X_train,y_train)
# pipe_g2 = Pipeline([('scaler',StandardScaler()),('classifier',SVC(kernel='linear',random_state=0))])
# pipe_g2.fit(X_train,y_train)
# pipe_g2.score(X_test,y_test)
# Out:
# SVC(kernel='linear', random_state=0)

# %%
svm.score(X_test,y_test)
# Out:
# 0.88

# %% [markdown]
# ##Q-3

# %%
from sklearn.metrics import confusion_matrix
y_pred = svm.predict(X_test)
cm = confusion_matrix(y_test,y_pred)
print(cm)
# Out:
# [[63  5]
#  [ 7 25]]

# %% [markdown]
# ##Q-4

# %%
from sklearn.datasets import fetch_openml
X,y = fetch_openml('mnist_784',version=1,return_X_y=True)

# %%
X.shape
# Out:
# (70000, 784)

# %%
y.shape
# Out:
# (70000,)

# %%
X_train=X[:20000]
y_train=y[:20000]
X_test=X[20000:25000]
y_test=y[20000:25000]

# %%
pipe_g4 = Pipeline([('scaler',MinMaxScaler()),('classifier',SVC(kernel='linear',decision_function_shape='ovr',class_weight=None))])
pipe_g4.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('scaler', MinMaxScaler()),
#                 ('classifier', SVC(kernel='linear'))])

# %%
from pandas._libs.algos import take_2d_axis0_float64_float64
y_pred = pipe_g4.predict(X_test)
cm=confusion_matrix(y_test,y_pred)
total=0
for i in range(len(cm)):
  for j in range(len(cm[0])):
    if i==j:
      total+=cm[i][j]
print(total)
# Out:
# 4623

# %% [markdown]
# ##Q-5

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.98      0.96       478
#            1       0.95      0.98      0.97       568
#            2       0.92      0.92      0.92       521
#            3       0.91      0.90      0.90       516
#            4       0.91      0.94      0.92       500
#            5       0.88      0.88      0.88       460
#            6       0.97      0.96      0.96       491
#            7       0.91      0.96      0.94       504
#            8       0.93      0.85      0.89       466
#            9       0.92      0.88      0.90       496
#
#     accuracy                           0.92      5000
#    macro avg       0.92      0.92      0.92      5000
# weighted avg       0.92      0.92      0.92      5000

# %% [markdown]
# ##Q-6

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.50,random_state=42)
pipe_g6 = Pipeline([('scaler',StandardScaler()),('classifier',SVC(kernel='poly',degree=3,decision_function_shape='ovr',class_weight='balanced',C=10))])
pipe_g6.fit(X_train,y_train)
y_pred = pipe_g6.predict(X_test)
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99      3463
#            1       0.99      0.99      0.99      3927
#            2       0.96      0.97      0.96      3520
#            3       0.98      0.96      0.97      3551
#            4       0.96      0.98      0.97      3333
#            5       0.97      0.97      0.97      3144
#            6       0.98      0.98      0.98      3490
#            7       0.98      0.97      0.97      3718
#            8       0.96      0.96      0.96      3344
#            9       0.96      0.96      0.96      3510
#
#     accuracy                           0.97     35000
#    macro avg       0.97      0.97      0.97     35000
# weighted avg       0.97      0.97      0.97     35000

# %% [markdown]
# ##Q-7

# %%
X,y = load_iris(return_X_y=True)
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3)
svm = SVC(kernel='poly',C=10,gamma='auto')
svm.fit(X_train,y_train)
svm.score(X_test,y_test)
# Out:
# 0.9777777777777777

# %% [markdown]
# ##Q-8

# %%
X,y = load_iris(return_X_y=True)
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3)
svm = SVC(kernel='sigmoid',C=25,gamma='auto')
svm.fit(X_train,y_train)
svm.score(X_test,y_test)
# Out:
# 0.26666666666666666

# %% [markdown]
# ##Q-9

# %%
data = load_iris(as_frame=True)
data.target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
idx=data.target[data.target==0]
idx_to_del=idx.index.values
labels=data.target.drop(index=idx_to_del)
features = data.data.drop(index=idx_to_del)
X=features.to_numpy()
y=labels.to_numpy()

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25,random_state=0)
pipe_g9 = Pipeline([('scaler',MinMaxScaler()),('classifier',SVC())])
pipe_g9.fit(X_train,y_train)
y_hat=pipe_g9.predict(X_test)
print(classification_report(y_test,y_hat))
# Out:
#               precision    recall  f1-score   support
#
#            1       1.00      0.85      0.92        13
#            2       0.86      1.00      0.92        12
#
#     accuracy                           0.92        25
#    macro avg       0.93      0.92      0.92        25
# weighted avg       0.93      0.92      0.92        25
