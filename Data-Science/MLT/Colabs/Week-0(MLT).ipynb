# %%
import numpy as np

# %%
x= np.array([[1,2,3],[4,5,6]])
y=np.array([[7,8],[9,10],[11,12]])
np.dot(x,y)
# Out:
# array([[ 58,  64],
#        [139, 154]])

# %%
x = np.array([1, 2, 3])
y = np.array([4, 5, 6])
print(x @ y)
# Out:
# 32
